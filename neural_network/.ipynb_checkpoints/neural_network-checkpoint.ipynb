# %% [markdown]
# # Training the Neural Net on Various Datasets #
#
# Make the required imports and set the chosen dataset to train the network on.

# %%
import tensorflow as tf
from tensorflow import keras
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

DATASET = 'american_extremes'

# %% [markdown]
# Load the tweets and target labels and calculate the size of a 10% split.

# %%
tf.compat.v1.enable_eager_execution()
tf.keras.backend.clear_session()

# %%
# Readlines into list of tweets and labels
with open('..\\dataset_creation\\datasets\\'+DATASET+'\\tweets.txt', encoding="utf8") as f:
    raw_tweets = f.readlines()

with open('..\\dataset_creation\\datasets\\'+DATASET+'\\labels.txt')as f:
    raw_labels = f.readlines()

# Create list of output targets
target_dataset = list()
for label in raw_labels:
    if label == '1\n':
        target_dataset.append(1)
    else:
        target_dataset.append(0)

# 
SPLIT = round(len(raw_tweets)*0.1)

# %% [markdown]
# Function to conduct the required preprocessing and convert the tweets and target labels to tensor objects padded with a default value to make all tensors the same size

# %%
def preprocess(X_batch, y_batch):
    X_batch = tf.strings.substr(X_batch, 0, 240)
    X_batch = tf.strings.regex_replace(X_batch, b"<br\\s*/?>", b" ")
    X_batch = tf.strings.regex_replace(X_batch, b"[^a-zA-Z']", b" ")
    X_batch = tf.strings.split(X_batch)
    y_batch = tf.convert_to_tensor(y_batch, dtype=tf.int64)
    return X_batch.to_tensor(default_value=b"<pad>"), y_batch

# %% [markdown]
# Preprocess the dataset and split 10% of for later testing.

# %%
X_batch, y_batch = preprocess(raw_tweets, target_dataset)

# %%
X_test, X_train_full = X_batch[:SPLIT], X_batch[SPLIT:]
y_test, y_train_full = y_batch[:SPLIT], y_batch[SPLIT:]

# %% [markdown]
# Create a vocabulary set based on the dataset and create a truncated vocabulary set of the 10,000 most common words.

# %%
vocabulary = Counter()
for tweet in X_train_full:
    vocabulary.update(list(tweet.numpy()))

# %%
vocab_size = 10000
truncated_vocabulary = [
    word for word, count in vocabulary.most_common()[:vocab_size]
]

# %% [markdown]
# Create a look up table of the 10,000 most common words and 1,000 out of value buckets

# %%
words = tf.constant(truncated_vocabulary)
word_ids = tf.range(len(truncated_vocabulary), dtype=tf.int64)
vocab_init = tf.lookup.KeyValueTensorInitializer(words, word_ids)
num_oov_buckets = 1000
table = tf.lookup.StaticVocabularyTable(vocab_init, num_oov_buckets)

# %% [markdown]
# Define function that takes a matrix of tweet tensors and returns a matrix of tweets with corresponding index values inpaplace of words. Pass the training set through the function and split off a validation set.

# %%
def encode_words(dataset_input):
    return table.lookup(dataset_input)

# %%
X_valid, X_train = encode_words(X_train_full[:SPLIT]), encode_words(X_train_full[SPLIT:])
y_valid, y_train = y_train_full[:SPLIT], y_train_full[SPLIT:]

# %% [markdown]
# Define network layers and set embedding layer size to size of tweet tensors. Mask zero is set to true to ignore the most common word which will be the padding token.

# %%
embed_size = X_batch.shape[1]
dropout = 0.5
model = keras.models.Sequential([
    keras.layers.Embedding(vocab_size + num_oov_buckets, embed_size, mask_zero=True),
    keras.layers.Dropout(dropout),
    keras.layers.GRU(256),
    keras.layers.Dropout(dropout),
    keras.layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# Compile the modile call the summary function to show the layers and parameters.  Run the network for 10 epochs.

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 61)          671000
# _________________________________________________________________
# dropout (Dropout)            (None, None, 61)          0
# _________________________________________________________________
# gru (GRU)                    (None, 256)               244992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 916,249
# Trainable params: 916,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Train on 34772 samples, validate on 4346 samples
# Epoch 1/10
# 34772/34772 [==============================] - 218s 6ms/sample - loss: 0.2238 - accuracy: 0.9102 - val_loss: 0.1452 - val_accuracy: 0.9413
# Epoch 2/10
# 34772/34772 [==============================] - 233s 7ms/sample - loss: 0.1029 - accuracy: 0.9590 - val_loss: 0.1388 - val_accuracy: 0.9478
# Epoch 3/10
# 34772/34772 [==============================] - 278s 8ms/sample - loss: 0.0712 - accuracy: 0.9725 - val_loss: 0.1477 - val_accuracy: 0.9464
# Epoch 4/10
# 34772/34772 [==============================] - 367s 11ms/sample - loss: 0.0517 - accuracy: 0.9804 - val_loss: 0.1768 - val_accuracy: 0.9439
# Epoch 5/10
# 34772/34772 [==============================] - 364s 10ms/sample - loss: 0.0361 - accuracy: 0.9861 - val_loss: 0.1867 - val_accuracy: 0.9455
# Epoch 6/10
# 34772/34772 [==============================] - 408s 12ms/sample - loss: 0.0271 - accuracy: 0.9898 - val_loss: 0.2051 - val_accuracy: 0.9464
# Epoch 7/10
# 34772/34772 [==============================] - 442s 13ms/sample - loss: 0.0212 - accuracy: 0.9919 - val_loss: 0.2184 - val_accuracy: 0.9443
# Epoch 8/10
# 34772/34772 [==============================] - 557s 16ms/sample - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.2298 - val_accuracy: 0.9448
# Epoch 9/10
# 34772/34772 [==============================] - 578s 17ms/sample - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.2482 - val_accuracy: 0.9439
# Epoch 10/10
# 34772/34772 [==============================] - 603s 17ms/sample - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.2672 - val_accuracy: 0.9455

# %% [markdown]
# Represent the history from training the model in graph to show how well the model is generalising.

# %%
# Represent learning curves using pandas and matplotlib
pd.DataFrame(history.history).plot(figsize=(10, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.gca().set_xlim(0, 9)
plt.show()

# %%
X_test_encoded = encode_words(X_test)

# %%
model.evaluate(X_test_encoded, y_test)
# Out:
# 4346/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.3100558022163368, 0.94293606]

# %%
X_new = X_test_encoded[:10]
y_proba = model.predict(X_new)
for i in range(len(y_proba)):
    print(str(i+1) + ".\nPrediction: " + str(y_proba[i][0].round(2)) + "\nActual: " + str(y_test[i].numpy()) + "\n")
# Out:
# Prediction: 1.0
# Actual: 1
#
# 3.
# Prediction: 1.0
# Actual: 1
#
# Prediction: 1.0
# Actual: 1
#
# Prediction: 1.0
# Actual: 1
#
# 5.
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 1.0
# Actual: 1
#
# 7.
# Prediction: 1.0
# Actual: 1
#
# 8.
# Prediction: 0.0
# Actual: 0
#
# Prediction: 1.0
# Actual: 1

# %%
model.save(DATASET + '.h5')

# %%
new_model = keras.models.load_model(DATASET + '.h5')

# %%
X_new = X_test_encoded[:10]
new_y_proba = new_model.predict(X_new)
for i in range(len(new_y_proba)):
    print(str(i+1) + ".\nPrediction: " + str(new_y_proba[i][0].round(2)) + "\nActual: " + str(y_test[i].numpy()) + "\n")
# Out:
# Prediction: 1.0
# Actual: 1
#
# 3.
# Prediction: 1.0
# Actual: 1
#
# Prediction: 1.0
# Actual: 1
#
# Prediction: 1.0
# Actual: 1
#
# 5.
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 1.0
# Actual: 1
#
# 7.
# Prediction: 1.0
# Actual: 1
#
# 8.
# Prediction: 0.0
# Actual: 0
#
# Prediction: 1.0
# Actual: 1
