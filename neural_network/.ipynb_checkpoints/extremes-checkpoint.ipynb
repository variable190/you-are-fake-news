# %% [markdown]
# # Extremes #
# This dataset is made up of tweets that link to news outlets that are seen as extremely partisan. Breitbart on the right, labelled 0, and Slate and The NewYorker on the left, labelled 1. The set contains about 30,000 tweets.
#
# Import libraries and load dataset

# %%
import tensorflow as tf
from tensorflow import keras
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

DATASET = 'extremes'

tf.compat.v1.enable_eager_execution()
tf.keras.backend.clear_session()

# %%
with open('..\\dataset_creation\\datasets\\'+DATASET+'\\tweets.txt', encoding="utf8") as f:
    raw_tweets = f.readlines()

with open('..\\dataset_creation\\datasets\\'+DATASET+'\\labels.txt')as f:
    raw_labels = f.readlines()

target_dataset = list()
for label in raw_labels:
    if label == '1\n':
        target_dataset.append(1)
    else:
        target_dataset.append(0)

SPLIT = round(len(raw_tweets)*0.1)

# %% [markdown]
# Split test set and preprocess data

# %%
def preprocess(X_batch, y_batch):
    X_batch = tf.strings.substr(X_batch, 0, 240)
    X_batch = tf.strings.regex_replace(X_batch, b"<br\\s*/?>", b" ")
    X_batch = tf.strings.regex_replace(X_batch, b"[^a-zA-Z']", b" ")
    X_batch = tf.strings.split(X_batch)
    y_batch = tf.convert_to_tensor(y_batch, dtype=tf.int64)
    return X_batch.to_tensor(default_value=b"<pad>"), y_batch

# %%
X_batch, y_batch = preprocess(raw_tweets, target_dataset)

# %%
X_test, X_train_full = X_batch[:SPLIT], X_batch[SPLIT:]
y_test, y_train_full = y_batch[:SPLIT], y_batch[SPLIT:]

# %% [markdown]
# Create vocabulary lookup table

# %%
vocabulary = Counter()
for tweet in X_train_full:
    vocabulary.update(list(tweet.numpy()))

# %%
vocab_size = 10000
truncated_vocabulary = [
    word for word, count in vocabulary.most_common()[:vocab_size]
]

# %%
words = tf.constant(truncated_vocabulary)
word_ids = tf.range(len(truncated_vocabulary), dtype=tf.int64)
vocab_init = tf.lookup.KeyValueTensorInitializer(words, word_ids)
num_oov_buckets = 1000
table = tf.lookup.StaticVocabularyTable(vocab_init, num_oov_buckets)

# %% [markdown]
# Split validation set and encode words with look up table

# %%
def encode_words(dataset_input):
    return table.lookup(dataset_input)

# %%
X_valid, X_train = encode_words(X_train_full[:SPLIT]), encode_words(X_train_full[SPLIT:])
y_valid, y_train = y_train_full[:SPLIT], y_train_full[SPLIT:]

# %% [markdown]
# Define, compile and run model

# %%
embed_size = 8
model7 = keras.models.Sequential([
    keras.layers.Embedding(vocab_size + num_oov_buckets, embed_size, mask_zero=True),
    keras.layers.GRU(embed_size, dropout=0.5, activation="sigmoid", return_sequences=True),
    keras.layers.GRU(embed_size, dropout=0.5, activation="sigmoid"),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model7.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 8)           88000
# _________________________________________________________________
# gru (GRU)                    (None, None, 8)           432
# _________________________________________________________________
# gru_1 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 88,873
# Trainable params: 88,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
history7 = model7.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Train on 23706 samples, validate on 2963 samples
# Epoch 1/10
# 23706/23706 [==============================] - 89s 4ms/sample - loss: 0.7038 - accuracy: 0.5463 - val_loss: 0.6511 - val_accuracy: 0.7779
# Epoch 2/10
# 23706/23706 [==============================] - 93s 4ms/sample - loss: 0.5200 - accuracy: 0.7701 - val_loss: 0.3624 - val_accuracy: 0.8613
# Epoch 3/10
# 23706/23706 [==============================] - 107s 5ms/sample - loss: 0.3735 - accuracy: 0.8485 - val_loss: 0.3149 - val_accuracy: 0.8832
# Epoch 4/10
# 23706/23706 [==============================] - 131s 6ms/sample - loss: 0.3137 - accuracy: 0.8817 - val_loss: 0.2946 - val_accuracy: 0.8903
# Epoch 5/10
# 23706/23706 [==============================] - 182s 8ms/sample - loss: 0.2723 - accuracy: 0.9019 - val_loss: 0.2878 - val_accuracy: 0.8893
# Epoch 6/10
# 23706/23706 [==============================] - 262s 11ms/sample - loss: 0.2505 - accuracy: 0.9126 - val_loss: 0.2889 - val_accuracy: 0.8910
# Epoch 7/10
# 23706/23706 [==============================] - 282s 12ms/sample - loss: 0.2389 - accuracy: 0.9188 - val_loss: 0.2907 - val_accuracy: 0.8890
# Epoch 8/10
# 23706/23706 [==============================] - 299s 13ms/sample - loss: 0.2242 - accuracy: 0.9247 - val_loss: 0.2937 - val_accuracy: 0.8886
# Epoch 9/10
# 23706/23706 [==============================] - 336s 14ms/sample - loss: 0.2139 - accuracy: 0.9282 - val_loss: 0.2982 - val_accuracy: 0.8907
# Epoch 10/10
# 23706/23706 [==============================] - 350s 15ms/sample - loss: 0.2051 - accuracy: 0.9326 - val_loss: 0.2980 - val_accuracy: 0.8907

# %% [markdown]
# Display model training with pandas and matplot libraries

# %%
pd.DataFrame(history7.history).plot(figsize=(10, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.gca().set_xlim(0, 9)
plt.show()

# %% [markdown]
# Evaluate model with test set and print first ten predictions and labels

# %%
X_test_encoded = encode_words(X_test)

# %%
model7.evaluate(X_test_encoded, y_test)
# Out:
# 2963/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.2861399788923695, 0.8957138]

# %%
X_new = X_test_encoded[:10]
y_proba = model7.predict(X_new)
for i in range(len(y_proba)):
    print(str(i+1) + ".\nPrediction: " + str(y_proba[i][0].round(2)) + "\nActual: " + str(y_test[i].numpy()) + "\n")
# Out:
# 1.
# Prediction: 0.89
# Actual: 1
#
# 2.
# Prediction: 0.97
# Actual: 1
#
# 3.
# Prediction: 0.96
# Actual: 1
#
# 4.
# Prediction: 0.97
# Actual: 1
#
# 5.
# Prediction: 0.97
# Actual: 1
#
# 6.
# Prediction: 0.02
# Actual: 1
#
# 7.
# Prediction: 0.02
# Actual: 0
#
# 8.
# Prediction: 0.96
# Actual: 0
#
# 9.
# Prediction: 0.02
# Actual: 1
#
# 10.
# Prediction: 0.02
# Actual: 0

# %% [markdown]
# Save model and test saved model by loading and comparing first ten predictions with the ten above

# %%
model7.save("saved_models\\" + DATASET + '.h5')

# %%
new_model = keras.models.load_model("saved_models\\" + DATASET + '.h5')

# %%
X_new = X_test_encoded[:10]
new_y_proba = new_model.predict(X_new)
for i in range(len(new_y_proba)):
    print(str(i+1) + ".\nPrediction: " + str(new_y_proba[i][0].round(2)) + "\nActual: " + str(y_test[i].numpy()) + "\n")
# Out:
# 1.
# Prediction: 0.89
# Actual: 1
#
# 2.
# Prediction: 0.97
# Actual: 1
#
# 3.
# Prediction: 0.96
# Actual: 1
#
# 4.
# Prediction: 0.97
# Actual: 1
#
# 5.
# Prediction: 0.97
# Actual: 1
#
# 6.
# Prediction: 0.02
# Actual: 1
#
# 7.
# Prediction: 0.02
# Actual: 0
#
# 8.
# Prediction: 0.96
# Actual: 0
#
# 9.
# Prediction: 0.02
# Actual: 1
#
# 10.
# Prediction: 0.02
# Actual: 0
