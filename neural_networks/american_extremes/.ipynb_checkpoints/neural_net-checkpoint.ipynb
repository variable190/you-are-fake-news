# %%
# Readlines into list of tweets and labels
f = open('tweets.txt', encoding="utf8")
raw_tweets = f.readlines()
f.close()

f = open('labels.txt')
raw_labels = f.readlines()
f.close()

# Create list of output targets
target_dataset = list()
for label in raw_labels:
    if label == '1\n':
        target_dataset.append(1)
    else:
        target_dataset.append(0)

# %%
import tensorflow as tf

def preprocess(X_batch, y_batch):
    X_batch = tf.strings.substr(X_batch, 0, 240)
    X_batch = tf.strings.regex_replace(X_batch, b"<br\\s*/?>", b" ")
    X_batch = tf.strings.regex_replace(X_batch, b"[^a-zA-Z']", b" ")
    X_batch = tf.strings.split(X_batch)
    y_batch = tf.convert_to_tensor(y_batch, dtype=tf.int64)
    return X_batch.to_tensor(default_value=b"<pad>"), y_batch

# %%
X_batch, y_batch = preprocess(raw_tweets, target_dataset)

# %%
X_test, X_train_full = X_batch[:8000], X_batch[8000:]
y_test, y_train_full = y_batch[:8000], y_batch[8000:]

# %%
from collections import Counter
import numpy

vocabulary = Counter()
for review in X_train_full:
    vocabulary.update(list(review.numpy()))

# %%
vocab_size = 15000
truncated_vocabulary = [
    word for word, count in vocabulary.most_common()[:vocab_size]
]

# %%
words = tf.constant(truncated_vocabulary)
word_ids = tf.range(len(truncated_vocabulary), dtype=tf.int64)
vocab_init = tf.lookup.KeyValueTensorInitializer(words, word_ids)
num_oov_buckets = 1000
table = tf.lookup.StaticVocabularyTable(vocab_init, num_oov_buckets)

# %%
def encode_words(dataset_input):
    return table.lookup(dataset_input)

# %%
X_valid, X_train = encode_words(X_train_full[:6000]), encode_words(X_train_full[6000:])
y_valid, y_train = y_train_full[:6000], y_train_full[6000:]

# %%
from tensorflow import keras

embed_size = 128
model = keras.models.Sequential([
    keras.layers.Embedding(vocab_size + num_oov_buckets, embed_size, mask_zero=True, input_shape=[None]),
    keras.layers.GRU(128, return_sequences=True),
    keras.layers.GRU(128),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Train on 29464 samples, validate on 6000 samples
# Epoch 1/5
# 29464/29464 [==============================] - 122s 4ms/sample - loss: 0.1997 - accuracy: 0.9190 - val_loss: 0.1386 - val_accuracy: 0.9505
# Epoch 2/5
# 29464/29464 [==============================] - 122s 4ms/sample - loss: 0.0704 - accuracy: 0.9743 - val_loss: 0.1490 - val_accuracy: 0.9483
# Epoch 3/5
# 29464/29464 [==============================] - 134s 5ms/sample - loss: 0.0276 - accuracy: 0.9905 - val_loss: 0.1832 - val_accuracy: 0.9465
# Epoch 4/5
# 29464/29464 [==============================] - 153s 5ms/sample - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.2906 - val_accuracy: 0.9460
# Epoch 5/5
# 29464/29464 [==============================] - 182s 6ms/sample - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.2440 - val_accuracy: 0.9458

# %%
# Represent learning curves using pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
X_test_encoded = encode_words(X_test)

# %%
model.evaluate(X_test_encoded, y_test)
# Out:
# 8000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.2866933981010807, 0.940375]

# %%
X_new = X_test_encoded[:10]
y_proba = model.predict(X_new)
for i in range(len(y_proba)):
    print("Prediction: " + str(y_proba[i][0].round(2)) + "\nActual: " + str(y_test[i].numpy()) + "\n")
# Out:
# Prediction: 1.0
# Actual: 1
#
# Prediction: 0.98
# Actual: 1
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 1.0
# Actual: 1
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
#
# Prediction: 0.0
# Actual: 0
